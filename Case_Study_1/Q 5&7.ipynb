# %%
import pandas as pd

# %%
data = pd.read_csv('Data.csv')

# %%
data.head()
# Out:
#                                                 Data
# 0  Watch or listen live weekdays at 8:30am MT at ...
# 1  Watch or listen live weekdays at 8:30am MT at ...
# 2               Chubby And Hot, Always Stir The Pot!
# 3               Chubby And Hot, Always Stir The Pot!
# 4  Journalist, publisher of Rebel News — telling ...

# %% [markdown]
# # Q5: How many records contain a decimal number?

# %%
decimal_pattern = r'\d+\.\d+'
decimal_records = data[data['Data'].str.contains(decimal_pattern, regex=True, na=False)]
decimal_count = len(decimal_records)

print(f"Number of records with decimal numbers: {decimal_count}\n")

if not decimal_records.empty:
    # Count duplicates
    duplicate_counts = decimal_records['Data'].value_counts()
    
    print("=" * 80)
    print("RECORDS WITH DECIMAL NUMBERS (UNIQUE RECORDS WITH DUPLICATE COUNTS)")
    print("=" * 80)
    
    # Track printed records to avoid repeats
    printed_records = set()
    
    for record in decimal_records['Data']:
        if record not in printed_records:
            printed_records.add(record)
            
            count = duplicate_counts[record]
            print("\n" + "=" * 150)
            print(f"[ORIGINAL RECORD] (Appears {count} time{'s' if count > 1 else ''})")
            print("-" * 150)
            print(repr(record))
            
            # Extract and display decimal numbers
            import re
            decimals = re.findall(r'\d+\.\d+', record)
            print("\n[DECIMAL NUMBERS FOUND]:")
            print("-" * 150)
            print(", ".join(decimals))
            print("=" * 150 + "\n")
else:
    print("No records contain decimal numbers.")
# Out:
# Number of records with decimal numbers: 27
#
# ================================================================================
# RECORDS WITH DECIMAL NUMBERS (UNIQUE RECORDS WITH DUPLICATE COUNTS)
# ================================================================================
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# "Don Hladiuk is Calgary's eye on astronomy & space science news. On the CBC EyeOpener 1010AM or 99.1FM on the 1st or 2nd Monday of the month at 7:36 AM MT."
#
# [DECIMAL NUMBERS FOUND]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 99.1
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 8 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'AIR 106.1 FM + DiscoverAirdrie Local News.\nWant to win a truck? Our Ram Everyday Adventure Contest is BACK!\n\n@RadioClaireMC'
#
# [DECIMAL NUMBERS FOUND]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 106.1
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'hier schreiben die Hühner aus dem Stall  (*25./26.4. 2019) . \nKörner und Würmer immer willkommen'
#
# [DECIMAL NUMBERS FOUND]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 26.4
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 5 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Providing RV repair, parts & accessories, 24/7 mobile service, custom rebuilds, rentals & quality advice from Red Seal Certified RV Technicians. +1.587.989.1271'
#
# [DECIMAL NUMBERS FOUND]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 1.587, 989.1271
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# '#openaccess journal published by@MDPIOpenAccess, covering aspects of #landscience. IF 2021: 3.905; CiteScore 2021: 3.2.\n#LULC #landscape #soil #urban #climate'
#
# [DECIMAL NUMBERS FOUND]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 3.905, 3.2
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Hoping hardcore twitter 2.0 lets me express honest opinions about Danielle Smith\'s supporters.\n\n"Let them see what is on the end of that long newspaper spoon."'
#
# [DECIMAL NUMBERS FOUND]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2.0
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# "Playing Southern Saskatchewan's Best Country! Country 100.7 FM!"
#
# [DECIMAL NUMBERS FOUND]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 100.7
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# '96.5 CKFM - All Hit Country!\n📻 96.5 FM \n🌐 ckfm.ca \nYour source for everything happening in Mountain View County!'
#
# [DECIMAL NUMBERS FOUND]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 96.5, 96.5
# ======================================================================================================================================================

# %% [markdown]
# # Q7: Howmanyrecords have a new line?

# %%
newline_pattern = r'\n'
newline_records = data[data['Data'].str.contains(newline_pattern, regex=True, na=False)]
newline_count = len(newline_records)

print(f"Number of records with newlines: {newline_count}\n")

if not newline_records.empty:
    # Count duplicates
    duplicate_counts = newline_records['Data'].value_counts()
    
    print("=" * 80)
    print("RECORDS WITH NEWLINES (UNIQUE RECORDS WITH DUPLICATE COUNTS)")
    print("=" * 80)
    
    # Track printed records to avoid repeats
    printed_records = set()
    
    for record in newline_records['Data']:
        if record not in printed_records:
            printed_records.add(record)
            
            count = duplicate_counts[record]
            print("\n" + "=" * 150)
            print(f"[ORIGINAL RECORD] (Appears {count} time{'s' if count > 1 else ''})")
            print("-" * 150)
            print(repr(record))
            
            print("\n[RENDERED WITH LINE BREAKS]:")
            print("-" * 150)
            print(record)
            print("=" * 150 + "\n")
else:
    print("No records contain newline characters.")
# Out:
# Number of records with newlines: 1211
#
# ================================================================================
# RECORDS WITH NEWLINES (UNIQUE RECORDS WITH DUPLICATE COUNTS)
# ================================================================================
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Think-tank president. Out-of-touch opinion elite. Proud husband of a teacher. Albertan. 🌈 #LGBTQally (he/him)\nMastodon: @seandunn@hachyderm.io'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Think-tank president. Out-of-touch opinion elite. Proud husband of a teacher. Albertan. 🌈 #LGBTQally (he/him)
# Mastodon: @seandunn@hachyderm.io
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 8 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Traveller, nature lover, photographer. HR Professional by day & MBA Candidate. Calgarian. He/him\nOpinions are my own and do not represent any org.'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Traveller, nature lover, photographer. HR Professional by day & MBA Candidate. Calgarian. He/him
# Opinions are my own and do not represent any org.
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# "📌 Eloquent AF\n📌 Anti-Conservative\n📌 No time for CPC/UCP trolls\n📌 Treaty 7 settler\n📌 Frankly, my dear, I don't give a fuck"
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 📌 Eloquent AF
# 📌 Anti-Conservative
# 📌 No time for CPC/UCP trolls
# 📌 Treaty 7 settler
# 📌 Frankly, my dear, I don't give a fuck
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 8 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'When I look at the mess that is Alberta under the UCP I know I will #NeverVoteConservative\nTweets are my opinion 🏳️\u200d🌈\n@CanadianInAB@mstdn.ca'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# When I look at the mess that is Alberta under the UCP I know I will #NeverVoteConservative
# Tweets are my opinion 🏳️‍🌈
# @CanadianInAB@mstdn.ca
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# "Alberta's Most Followed War Room--double the followers at $30mill/yr less.\nStompers of UCP Mediocre Bros. Médecins Sans F__ks™️."
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Alberta's Most Followed War Room--double the followers at $30mill/yr less.
# Stompers of UCP Mediocre Bros. Médecins Sans F__ks™️.
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 6 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Ban semi auto rifles w/detachable magazines and handguns as part of a gun violence harm-reduction strategy\n\nNo gun or no ammo = no shooting'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Ban semi auto rifles w/detachable magazines and handguns as part of a gun violence harm-reduction strategy
#
# No gun or no ammo = no shooting
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Teacher\n\nHe/Him'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Teacher
#
# He/Him
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Photographer, storm chaser, counsellor, and pop culture addict. Member of @prairiechasers. She/Her\n(also @adolwyn@mas.to)'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# "Wildlife Photographer/Amateur Naturalist. \n\nImages can be viewed through my website. No baiting practices are used. Take a moment to view Alberta's wildlife."
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Wildlife Photographer/Amateur Naturalist.
#
# Images can be viewed through my website. No baiting practices are used. Take a moment to view Alberta's wildlife.
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 12 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Luthier, Lorax, Env-Journalist & Activist, The Crowsnest Journal\n\n"I no longer know where I end and the land and streams begin"'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Luthier, Lorax, Env-Journalist & Activist, The Crowsnest Journal
#
# "I no longer know where I end and the land and streams begin"
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# "I'm gone for a while till EM stops running this place into the ground.\n\nlinkedin.com/in/noaharney/"
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# I'm gone for a while till EM stops running this place into the ground.
#
# linkedin.com/in/noaharney/
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Retired, Mom, Wife, Grammoe, Love to read and follow politics.🐔🍷☘️🦂 And \n grow Brugmansias!   @brugmansia1@mstdn.ca'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Retired, Mom, Wife, Grammoe, Love to read and follow politics.🐔🍷☘️🦂 And
#  grow Brugmansias!   @brugmansia1@mstdn.ca
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 16 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Working to inspire Alberta’s communities to care about wilderness and wildlife through awareness and action.\nSee also @Adventures4Wild.'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Working to inspire Alberta’s communities to care about wilderness and wildlife through awareness and action.
# See also @Adventures4Wild.
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Not actually a 17th century Cossack general. I thought this was obvious. \n\nAlso not a Russian bot just because I used the name "Ivan". \n\nSometimes parody.'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Not actually a 17th century Cossack general. I thought this was obvious.
#
# Also not a Russian bot just because I used the name "Ivan".
#
# Sometimes parody.
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'African American Travel Historian\nBlack History Is More Than 28 Days'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# African American Travel Historian
# Black History Is More Than 28 Days
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 8 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# "Alberta Legislature reporter for AB Today.\nRTs do not equal endorsements.\nLive tweets aren't the official transcript.\n\nemail: catherine (at) abtoday dot ca"
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Alberta Legislature reporter for AB Today.
# RTs do not equal endorsements.
# Live tweets aren't the official transcript.
#
# email: catherine (at) abtoday dot ca
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# "#GunControlNow  #ClimateBrawl   #LTCJustice. #Reconciliation\nLet's not vote for the Convoy Party of Canada\npost.news/Dvdnlsn\nMastadon @dvdnlsn@mstdn.ca"
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# #GunControlNow  #ClimateBrawl   #LTCJustice. #Reconciliation
# Let's not vote for the Convoy Party of Canada
# post.news/Dvdnlsn
# Mastadon @dvdnlsn@mstdn.ca
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 167 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Outdoor Adventures & Road Trips ⛺🚲🛶 \nWriter, Radio/TV Guest Speaker, Influencer, #ABparksambassador\nFollow our adventures at Play Outside Guide.⤵️'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Outdoor Adventures & Road Trips ⛺🚲🛶
# Writer, Radio/TV Guest Speaker, Influencer, #ABparksambassador
# Follow our adventures at Play Outside Guide.⤵️
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'First Nations advocate. Ex anti-racism facilitator. Dakelh FN Survived rez school, white feminism, sexual abuse. NO LISTS\npaypal.me/CGeorge157?loc…'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# First Nations advocate. Ex anti-racism facilitator. Dakelh FN Survived rez school, white feminism, sexual abuse. NO LISTS
# paypal.me/CGeorge157?loc…
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Radical pragmatist -\nCo-founder @DVSociety'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Radical pragmatist -
# Co-founder @DVSociety
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# '#ProudDyslexic #MentalHealthProfession #AgentofChange\n\nMake a difference, not a mess❣\n\nFuck is not a bad word'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------

#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Sports Reporter @PADailyHerald
# Lethbridge College DCM Alum.
# YQL born and raised. My tweets and opinions are my own.
# Story idea? Email me: sports@paherald.sk.ca
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Community & economy builder, city planner,  affordable housing, nature lover. Human being (she/her)\nTweets are my own'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Community & economy builder, city planner,  affordable housing, nature lover. Human being (she/her)
# Tweets are my own
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# "I believe in fighting for those who don't have a voice. \nI respect everyone. Not trying to win a popularity contest. Donate to those who are suffering."
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# I believe in fighting for those who don't have a voice.
# I respect everyone. Not trying to win a popularity contest. Donate to those who are suffering.
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Medical Professional.\n“Prevention is better than cure!” Video and photo enthusiast.\nMy RTs are not endorsement; but for record-keeping of tweets from  others.'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Medical Professional.
# “Prevention is better than cure!” Video and photo enthusiast.
# My RTs are not endorsement; but for record-keeping of tweets from  others.
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 3 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'New twin mom\n\nMorning News Anchor @citynewscalgary \n\nOptimist! \n\n\n\nTralala!'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# New twin mom
#
# Morning News Anchor @citynewscalgary
#
# Optimist!
#
#
#
# Tralala!
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# "funk is the highest form of human development\n\nhindutva / maga are the lowest, dofo #2\n\nGogol stan account. I hope you're OK during this fucking Pandemic!"
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# funk is the highest form of human development
#
# hindutva / maga are the lowest, dofo #2
#
# Gogol stan account. I hope you're OK during this fucking Pandemic!
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'The Twitter page of the Mad Kynge, Be welcome, friend! \n(RPG player and GM, lover of both Star Trek, Star Wars, Hockey, and cats - not always in that order)'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# The Twitter page of the Mad Kynge, Be welcome, friend!
# (RPG player and GM, lover of both Star Trek, Star Wars, Hockey, and cats - not always in that order)
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# "Alberta Gaming, Liquor & Cannabis' corporate account. \n\nThis account will not be monitored from December 24 to January 2 due to holiday closures."
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Alberta Gaming, Liquor & Cannabis' corporate account.
#
# This account will not be monitored from December 24 to January 2 due to holiday closures.
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'A private, exclusive community founded upon members helping one another in a trusted environment.\nPost Classifieds • Find/Post Jobs • Networking • Free to Join'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# A private, exclusive community founded upon members helping one another in a trusted environment.
# Post Classifieds • Find/Post Jobs • Networking • Free to Join
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'A jack of all trades is a master of none, but\xa0oftentimes better than a master of one\nI am not a Political Activist, I am a Humanist.\nLearner, Humanist'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# A jack of all trades is a master of none, but oftentimes better than a master of one
# I am not a Political Activist, I am a Humanist.
# Learner, Humanist
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Territory Manager Calgary to Fort St.John\n                                   \nPitbull Blades \nHLA Attachments \nHLA Snow \nHorst Wagons \nTubeline\nReist Industries'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Territory Manager Calgary to Fort St.John
#
# Pitbull Blades
# HLA Attachments
# HLA Snow
# Horst Wagons
# Tubeline
# Reist Industries
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'The wisdom was created before any thing, the intelligence that disposes every thing comes from farther than the beginning of time.\nking 👑 Salomon.'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# The wisdom was created before any thing, the intelligence that disposes every thing comes from farther than the beginning of time.
# king 👑 Salomon.
# ======================================================================================================================================================
#
#
# ======================================================================================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 'Radical Downtown Urbanite\nThe other place: @chrisdoyle78@yyc.bike'
#
# [RENDERED WITH LINE BREAKS]:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Radical Downtown Urbanite
# The other place: @chrisdoyle78@yyc.bike
# ======================================================================================================================================================
