# %%
import pandas as pd
import re

# %%
df = pd.read_csv('Data.csv')

# %%
df.head()
# Out:
#                                                 Data
# 0  Watch or listen live weekdays at 8:30am MT at ...
# 1  Watch or listen live weekdays at 8:30am MT at ...
# 2               Chubby And Hot, Always Stir The Pot!
# 3               Chubby And Hot, Always Stir The Pot!
# 4  Journalist, publisher of Rebel News — telling ...

# %% [markdown]
# # Q9: Code to substitute all non-alphanumeric characters with a new line

# %%
non_alnum_pattern = r'[^a-zA-Z0-9\s]'  
non_alnum_records = df[df['Data'].str.contains(non_alnum_pattern, regex=True, na=False)]
non_alnum_count = len(non_alnum_records)

print(f"Number of records with non-alphanumeric characters: {non_alnum_count}\n")

if not non_alnum_records.empty:
    # Create a copy of the affected records for display purposes
    display_records = non_alnum_records.copy()
    
    # Count duplicates
    duplicate_counts = display_records['Data'].value_counts()
    
    print("=" * 80)
    print("RECORDS WITH NON-ALPHANUMERIC CHARACTERS (UNIQUE RECORDS WITH COUNTS)")
    print("=" * 80)
    
    # Track printed records to avoid repeats
    printed_records = set()
    
    for record in display_records['Data']:
        if record not in printed_records:
            printed_records.add(record)
            
            count = duplicate_counts[record]
            print("\n" + "=" * 80)
            print(f"[ORIGINAL RECORD] (Appears {count} time{'s' if count > 1 else ''})")
            
            # Replace non-alphanumeric chars with newline
            modified_record = re.sub(
                r'[^a-zA-Z0-9\s]', 
                '\n', 
                record
            )
            
            print("\n[MODIFIED RECORD (Non-alphanumeric → Newline ]:")
            print("-" * 80)
            print(repr(modified_record))
    
    # ACTUALLY MODIFY THE DATAFRAME by replacing non-alphanumeric characters with newlines
    df['Data'] = df['Data'].str.replace(non_alnum_pattern, '\n', regex=True)
    print("\nAll non-alphanumeric characters in the 'Data' column have been replaced with newlines.")
else:
    print("No records contain non-alphanumeric characters.")
# Out:
# Number of records with non-alphanumeric characters: 7069
#
# ================================================================================
# RECORDS WITH NON-ALPHANUMERIC CHARACTERS (UNIQUE RECORDS WITH COUNTS)
# ================================================================================
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Watch or listen live weekdays at 8\n30am MT at ryanjespersen\ncom\n Subscribe via YouTube or your favourite podcast app\n \nRealTalkRJ'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Chubby And Hot\n Always Stir The Pot\n'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Journalist\n publisher of Rebel News \n telling the other side of the story\n Awarded the Queen\ns Diamond Jubilee Medal for advancing freedom of expression\n'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Edmonton City Councillor for \nWardM\ntis\n \nYEG Urban Planner\n Sustainability \n Sociologist\n Founder\n Cities\n climate action\n health\n inclusion\n She\nher \nyegcc'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 55 times)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Albertan\n Mom to children \n dogs\n Wife\n Friend\n Leader of the Alberta NDP\n Account run by Rachel Notley and staff\n She\nHer \nableg'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Former progressive conservative specializing in delivering satirical irony through interpretive dance since June 2018\n If anyone orders Merlot I\nm leaving\n'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 11 times)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'I\nm Kuno\n a Gov\nt qualified service dog in Alberta\n Canada\n My job is taking care of my person\n a bilateral amputee\n \nweatherdog \n Spokesdog for the disabled'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Think\ntank president\n Out\nof\ntouch opinion elite\n Proud husband of a teacher\n Albertan\n \n \nLGBTQally \nhe\nhim\n\r\nMastodon\n \nseandunn\nhachyderm\nio'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# '
n'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Bullied\n rejected many times\n Fell and stood for so many years\n Invisible most of the time\n Making people laugh is my strength\n  but deep inside Im broken \n\n'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Politics\n Oilers\n'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Mediocre white man\n Software engineer\n Node\njs team\n Architect and DX lead \nneofinancial\n Sandwich enthusiast\n He\nhim\n \niansu\nmas\nto\n'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Nerdy guy who likes hockey and punk rock\n'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Song Writer\nLover of the Creator\n Lorna\n Bear\n Kass\n Stella\n Mao Mao Treaty 6\nMNA4   \nSickNotWeak Tweets mine but brutally honest \nsteelers Fan'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Radical Downtown Urbanite\r\nThe other place\n \nchrisdoyle78\nyyc\nbike'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Formerly Agent for The Attorney General of Canada\n Department of Justice\n Alberta\n\n Currently\n Author and International Trade Consultant\n Alberta\n'
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
#
# [MODIFIED RECORD (Non-alphanumeric → Newline ]:
# --------------------------------------------------------------------------------
# 'Snow Valley Racing delivers competitive ski racing for athletes from 4 to 18 years of age through a variety of professionally run programs\n Links \n\n\n\n\n\n'
#
# All non-alphanumeric characters in the 'Data' column have been replaced with newlines.

# %% [markdown]
# ## Code to substitute all non-alphanumeric characters with a new line excluding time formats and .com formats in URLs and emails

# %%
non_alnum_pattern = r'(?!(?<=\d)[:\/](?=\d))[^a-zA-Z0-9\s]'  # Excludes time formats
non_alnum_records = df[df['Data'].str.contains(non_alnum_pattern, regex=True, na=False)]
non_alnum_count = len(non_alnum_records)

print(f"Number of records with non-alphanumeric characters: {non_alnum_count}\n")

if not non_alnum_records.empty:
    # Count duplicates
    duplicate_counts = non_alnum_records['Data'].value_counts()
    
    print("=" * 80)
    print("RECORDS WITH NON-ALPHANUMERIC CHARACTERS (UNIQUE RECORDS WITH COUNTS)")
    print("=" * 80)
    
    # Track printed records to avoid repeats
    printed_records = set()
    
    for record in non_alnum_records['Data']:
        if record not in printed_records:
            printed_records.add(record)
            
            count = duplicate_counts[record]
            print("\n" + "=" * 80)
            print(f"[ORIGINAL RECORD] (Appears {count} time{'s' if count > 1 else ''})")
            print("-" * 80)
            print(repr(record))
            
            # Replace non-alphanumeric chars with newline, preserving time/email/URL patterns
            modified_record = re.sub(
                r'(?!(?<=\d)[:\/](?=\d))'  # Don't replace : or / between digits (time/date)
                r'(?!(?:@|\.(?:com|org|net|edu|gov)\b))'  # Don't replace in emails/URLs
                r'[^a-zA-Z0-9\s]', 
                '\n', 
                record
            )
            
            print("\n[MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:")
            print("-" * 80)
            print(repr(modified_record))
            
            print("\n[MODIFIED RECORD with new lines]:")
            print("-" * 80)
            print(modified_record)
            print("=" * 80 + "\n")

    # ACTUALLY MODIFY THE DATAFRAME by replacing non-alphanumeric characters with newlines
    df['Data'] = df['Data'].str.replace(non_alnum_pattern, '\n', regex=True)
    print("\nAll non-alphanumeric characters in the 'Data' column have been replaced with newlines.")
else:
    print("No records contain non-alphanumeric characters.")
# Out:
# Number of records with non-alphanumeric characters: 7069
#
# ================================================================================
# RECORDS WITH NON-ALPHANUMERIC CHARACTERS (UNIQUE RECORDS WITH COUNTS)
# ================================================================================
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)

#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Think\ntank president\n Out\nof\ntouch opinion elite\n Proud husband of a teacher\n Albertan\n \n \nLGBTQally \nhe\nhim\n\r\nMastodon\n @seandunn@hachyderm\nio'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Think
# tank president
#  Out
# of
# touch opinion elite
#  Proud husband of a teacher
#  Albertan
#
#
# LGBTQally
# he
# him
#
# Mastodon
#  @seandunn@hachyderm
# io
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# --------------------------------------------------------------------------------
# 'Editor-in-Chief of The Counter Signal | Broadcasting Truth'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Editor\nin\nChief of The Counter Signal \n Broadcasting Truth'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Editor
# in
# Chief of The Counter Signal
#  Broadcasting Truth
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 58 times)
# --------------------------------------------------------------------------------
# "Bragg Creek & Kananaskis Outdoor Recreation is your guide to the outdoors in Kananaskis (Calgary's backyard)! facebook.com/BraggCreek"
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Bragg Creek \n Kananaskis Outdoor Recreation is your guide to the outdoors in Kananaskis \nCalgary\ns backyard\n\n facebook.com\nBraggCreek'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Bragg Creek
#  Kananaskis Outdoor Recreation is your guide to the outdoors in Kananaskis
# Calgary
# s backyard
#
#  facebook.com
# BraggCreek
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Default avatar or locked followers will be removed (locked accounts can DM to discuss). Crypto-bros will be blocked. DianeMariePosts@mstdn.ca|Same on Post.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Default avatar or locked followers will be removed \nlocked accounts can DM to discuss\n\n Crypto\nbros will be blocked\n DianeMariePosts@mstdn\nca\nSame on Post\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Default avatar or locked followers will be removed
# locked accounts can DM to discuss
#
#  Crypto
# bros will be blocked
#  DianeMariePosts@mstdn
# ca
# Same on Post
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# --------------------------------------------------------------------------------
# 'Law Professor. Tweeting about health, law, politics, policing, antiracism, sports, fashion & culture. #BlackLivesMatter. he/him 🧡. 🐘@thenaijalorian@mstdn.ca'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Law Professor\n Tweeting about health\n law\n politics\n policing\n antiracism\n sports\n fashion \n culture\n \nBlackLivesMatter\n he\nhim \n\n \n@thenaijalorian@mstdn\nca'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Law Professor
#  Tweeting about health
#  law
#  politics
#  policing
#  antiracism
#  sports
#  fashion
#  culture
#
# BlackLivesMatter
#  he
# him
#
#
# @thenaijalorian@mstdn
# ca
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'In-depth Calgary journalism. Our Nov/Dec edition is about public transit.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'In\ndepth Calgary journalism\n Our Nov\nDec edition is about public transit\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# In
# depth Calgary journalism
#  Our Nov
# Dec edition is about public transit
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 8 times)
# --------------------------------------------------------------------------------
# 'Traveller, nature lover, photographer. HR Professional by day & MBA Candidate. Calgarian. He/him\r\nOpinions are my own and do not represent any org.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Traveller\n nature lover\n photographer\n HR Professional by day \n MBA Candidate\n Calgarian\n He\nhim\r\nOpinions are my own and do not represent any org\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Traveller
#  nature lover
#  photographer
#  HR Professional by day
#  MBA Candidate
#  Calgarian
#  He
# him
# Opinions are my own and do not represent any org
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# --------------------------------------------------------------------------------
# 'Latest news and analysis from CBC News. 🇨🇦'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Latest news and analysis from CBC News\n \n\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Latest news and analysis from CBC News
#
#
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Dealing with Bipolar disorder one day at a time.Drug overdose survivor.#thygoddostexist Feeling good is good enough!🙂All photographs were taken by me.🚫DM‼️'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Dealing with Bipolar disorder one day at a time\nDrug overdose survivor\n\nthygoddostexist Feeling good is good enough\n\nAll photographs were taken by me\n\nDM\n\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Dealing with Bipolar disorder one day at a time
# Drug overdose survivor
#
# thygoddostexist Feeling good is good enough
#
# All photographs were taken by me
#
# DM
#
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Political love child of Jack Layton & Ann Richards. Transfusion Med Lab Ninja. Professional eye roller. Views expressed not that of my employer. She/Her'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Political love child of Jack Layton \n Ann Richards\n Transfusion Med Lab Ninja\n Professional eye roller\n Views expressed not that of my employer\n She\nHer'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Political love child of Jack Layton
#  Ann Richards
#  Transfusion Med Lab Ninja
#  Professional eye roller
#  Views expressed not that of my employer
#  She
# Her
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 12 times)
# --------------------------------------------------------------------------------
# '30-something YO; Lover of Stuff and Things, Reader of Science and History. We are on the precipice of something extraordinary Alberta.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# '30\nsomething YO\n Lover of Stuff and Things\n Reader of Science and History\n We are on the precipice of something extraordinary Alberta\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# 30
# something YO
#  Lover of Stuff and Things
#  Reader of Science and History
#  We are on the precipice of something extraordinary Alberta
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 6 times)
# --------------------------------------------------------------------------------
# 'Proud dad. Happy husband. Union member. Works in comms. I write about Alberta politics and history at Daveberta.Substack.com | ⛷🚵 he/him'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Proud dad\n Happy husband\n Union member\n Works in comms\n I write about Alberta politics and history at Daveberta\nSubstack.com \n \n\n he\nhim'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Proud dad
#  Happy husband
#  Union member
#  Works in comms
#  I write about Alberta politics and history at Daveberta
# Substack.com
#
#
#  he
# him
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 16 times)
# --------------------------------------------------------------------------------
# "MLA for Calgary-Buffalo, Official Opposition Municipal Affairs critic, Min of Finance 2015-19, 5 term YYC Councillor'95-2010. Music lover, runner & beer snob."
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'MLA for Calgary\nBuffalo\n Official Opposition Municipal Affairs critic\n Min of Finance 2015\n19\n 5 term YYC Councillor\n95\n2010\n Music lover\n runner \n beer snob\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# MLA for Calgary
# Buffalo
#  Official Opposition Municipal Affairs critic
#  Min of Finance 2015
# 19
#  5 term YYC Councillor
# 95
# 2010
#  Music lover
#  runner
#  beer snob
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# "📌 Eloquent AF\r\n📌 Anti-Conservative\r\n📌 No time for CPC/UCP trolls\r\n📌 Treaty 7 settler\r\n📌 Frankly, my dear, I don't give a fuck"
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# '\n Eloquent AF\r\n\n Anti\nConservative\r\n\n No time for CPC\nUCP trolls\r\n\n Treaty 7 settler\r\n\n Frankly\n my dear\n I don\nt give a fuck'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
#
#  Eloquent AF
#
#  Anti
# Conservative
#
#  No time for CPC
# UCP trolls
#
#  Treaty 7 settler
#
#  Frankly
#  my dear
#  I don
# t give a fuck
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Analyst in the energy sector, researcher and writer. Niya Nehiyaw et Francais (I am Cree & French). #Treaty4 #Metis #WapscuhPeyesis #Politics #Policy'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Analyst in the energy sector\n researcher and writer\n Niya Nehiyaw et Francais \nI am Cree \n French\n\n \nTreaty4 \nMetis \nWapscuhPeyesis \nPolitics \nPolicy'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Analyst in the energy sector
#  researcher and writer
#  Niya Nehiyaw et Francais
# I am Cree
#  French
#
#
# Treaty4
# Metis
# WapscuhPeyesis
# Politics
# Policy
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# '12th Gen (1634) Franco-Albertan. Engineer. Married with 4 kids. Adventurer/Environmentalist. Libertarian. Progressive. I block idiots. #WEXIT'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# '12th Gen \n1634\n Franco\nAlbertan\n Engineer\n Married with 4 kids\n Adventurer\nEnvironmentalist\n Libertarian\n Progressive\n I block idiots\n \nWEXIT'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# 12th Gen
# 1634
#  Franco
# Albertan
#  Engineer
#  Married with 4 kids
#  Adventurer
# Environmentalist
#  Libertarian
#  Progressive
#  I block idiots
#
# WEXIT
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# --------------------------------------------------------------------------------
# 'Alberta. Teacher. UCP has to go! Love Oilers and Bluejays. Not a wordsmith.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Alberta\n Teacher\n UCP has to go\n Love Oilers and Bluejays\n Not a wordsmith\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Alberta
#  Teacher
#  UCP has to go
#  Love Oilers and Bluejays
#  Not a wordsmith
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 8 times)
# --------------------------------------------------------------------------------
# 'When I look at the mess that is Alberta under the UCP I know I will #NeverVoteConservative\r\nTweets are my opinion 🏳️\u200d🌈\r\n@CanadianInAB@mstdn.ca'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'When I look at the mess that is Alberta under the UCP I know I will \nNeverVoteConservative\r\nTweets are my opinion \n\n\n\n\r\n@CanadianInAB@mstdn\nca'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# When I look at the mess that is Alberta under the UCP I know I will
# NeverVoteConservative
# Tweets are my opinion
#
#
#
#
# @CanadianInAB@mstdn
# ca
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# --------------------------------------------------------------------------------
# 'The official account for Travel Alberta. Join us as we #ExploreAlberta.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'The official account for Travel Alberta\n Join us as we \nExploreAlberta\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# The official account for Travel Alberta
#  Join us as we
# ExploreAlberta
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# --------------------------------------------------------------------------------
# "Alberta's Most Followed War Room--double the followers at $30mill/yr less.\r\nStompers of UCP Mediocre Bros. Médecins Sans F__ks™️."
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Alberta\ns Most Followed War Room\n\ndouble the followers at \n30mill\nyr less\n\r\nStompers of UCP Mediocre Bros\n M\ndecins Sans F\n\nks\n\n\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Alberta
# s Most Followed War Room
#
# double the followers at
# 30mill
# yr less
#
# Stompers of UCP Mediocre Bros
#  M
# decins Sans F
#
# ks
#
#
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Remarkable badass. Some call me BigFonda. she/her #FiretheUCP #fuckthepatriarchy'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Remarkable badass\n Some call me BigFonda\n she\nher \nFiretheUCP \nfuckthepatriarchy'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Remarkable badass
#  Some call me BigFonda
#  she
# her
# FiretheUCP
# fuckthepatriarchy
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Professor of Political Science, UCalgary. Making sense of Alberta politics, one flowchart at a time. lisayoung.substack.com She/her. Tweets my own.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Professor of Political Science\n UCalgary\n Making sense of Alberta politics\n one flowchart at a time\n lisayoung\nsubstack.com She\nher\n Tweets my own\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Professor of Political Science
#  UCalgary
#  Making sense of Alberta politics
#  one flowchart at a time
#  lisayoung
# substack.com She
# her
#  Tweets my own
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Ran for Mayor of Toronto. Founder, 8 80 Cities. Creator / host A Walk in the Park. Founder Toronto for Everyone.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Ran for Mayor of Toronto\n Founder\n 8 80 Cities\n Creator \n host A Walk in the Park\n Founder Toronto for Everyone\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Ran for Mayor of Toronto
#  Founder
#  8 80 Cities
#  Creator
#  host A Walk in the Park
#  Founder Toronto for Everyone
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 12 times)
# --------------------------------------------------------------------------------
# 'Photographer, Oilers Fan #photography  #yeg .'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Photographer\n Oilers Fan \nphotography  \nyeg \n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Photographer
#  Oilers Fan
# photography
# yeg
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# --------------------------------------------------------------------------------
# 'Poetry, politics, parenting. Very sweary. Engaged to @meganbielby. Nobel Peace Prize nominee. Prime Minister Elect. Non-practising drunk. 🍄'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Poetry\n politics\n parenting\n Very sweary\n Engaged to @meganbielby\n Nobel Peace Prize nominee\n Prime Minister Elect\n Non\npractising drunk\n \n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Poetry
#  politics
#  parenting
#  Very sweary
#  Engaged to @meganbielby
#  Nobel Peace Prize nominee
#  Prime Minister Elect
#  Non
# practising drunk
#
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# "Breaking national and international news alerts from CBC News, Canada's TV, radio, online and social media news leader."
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Breaking national and international news alerts from CBC News\n Canada\ns TV\n radio\n online and social media news leader\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Breaking national and international news alerts from CBC News
#  Canada
# s TV
#  radio
#  online and social media news leader
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 12 times)
# --------------------------------------------------------------------------------
# "Just me, trying to be a good ancestor. She/Her. Running for Alberta's NDP in Calgary-Bow. @druhfarrell@mstdn.ca"
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Just me\n trying to be a good ancestor\n She\nHer\n Running for Alberta\ns NDP in Calgary\nBow\n @druhfarrell@mstdn\nca'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Just me
#  trying to be a good ancestor
#  She
# Her
#  Running for Alberta
# s NDP in Calgary
# Bow
#  @druhfarrell@mstdn
# ca
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# --------------------------------------------------------------------------------
# 'True North is a Canadian digital media platform focused on breaking news and investigative reporting.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'True North is a Canadian digital media platform focused on breaking news and investigative reporting\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# True North is a Canadian digital media platform focused on breaking news and investigative reporting
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# "Lucy's Edmonton Advocates Project wants the Valley Zoo to allow an expert, impartial vet to perform a medical assessment of Lucy the lone elephant. #RetireLucy"
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Lucy\ns Edmonton Advocates Project wants the Valley Zoo to allow an expert\n impartial vet to perform a medical assessment of Lucy the lone elephant\n \nRetireLucy'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Lucy
# s Edmonton Advocates Project wants the Valley Zoo to allow an expert
#  impartial vet to perform a medical assessment of Lucy the lone elephant
#
# RetireLucy
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Dinosaur paleontologist at the Royal Ontario Museum @ROMToronto & Assoc Prof at @UofT. Member of @RSCTheAcademies, Fellow of @RCGS_SGRC. Opinions my own.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Dinosaur paleontologist at the Royal Ontario Museum @ROMToronto \n Assoc Prof at @UofT\n Member of @RSCTheAcademies\n Fellow of @RCGS\nSGRC\n Opinions my own\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Dinosaur paleontologist at the Royal Ontario Museum @ROMToronto
#  Assoc Prof at @UofT
#  Member of @RSCTheAcademies
#  Fellow of @RCGS
# SGRC
#  Opinions my own
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Our stories told our way.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Our stories told our way\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Our stories told our way
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 30 times)
# --------------------------------------------------------------------------------
# 'We work to protect and preserve wild ecosystems, parks and protected areas in Southern Alberta and the Rocky Mountain parks. #DefendABParks'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'We work to protect and preserve wild ecosystems\n parks and protected areas in Southern Alberta and the Rocky Mountain parks\n \nDefendABParks'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# We work to protect and preserve wild ecosystems
#  parks and protected areas in Southern Alberta and the Rocky Mountain parks
#
# DefendABParks
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 5 times)
# --------------------------------------------------------------------------------
# 'Political geek. Joe Clark Enthusiast. Advocate for Sexual Violence survivors. Advisor/Interim Chair @parityyeg/ #ibelieveyou #metoo Opinions are my own'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Political geek\n Joe Clark Enthusiast\n Advocate for Sexual Violence survivors\n Advisor\nInterim Chair @parityyeg\n \nibelieveyou \nmetoo Opinions are my own'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Political geek
#  Joe Clark Enthusiast
#  Advocate for Sexual Violence survivors
#  Advisor
# Interim Chair @parityyeg
#
# ibelieveyou
# metoo Opinions are my own
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Family Doctor, enjoys hiking, biking, motorcycling, and... you, I like you #Abdocs4patients'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Family Doctor\n enjoys hiking\n biking\n motorcycling\n and\n\n\n you\n I like you \nAbdocs4patients'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Family Doctor
#  enjoys hiking
#  biking
#  motorcycling
#  and
#
#
#  you
#  I like you
# Abdocs4patients
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# --------------------------------------------------------------------------------
# 'We live in a time of lies & misinformation, of fascism & racism. The right wing & their leaders have made this behaviour acceptable. I will always push back.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'We live in a time of lies \n misinformation\n of fascism \n racism\n The right wing \n their leaders have made this behaviour acceptable\n I will always push back\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# We live in a time of lies
#  misinformation
#  of fascism
#  racism
#  The right wing
#  their leaders have made this behaviour acceptable
#  I will always push back
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 6 times)
# --------------------------------------------------------------------------------
# 'Ban semi auto rifles w/detachable magazines and handguns as part of a gun violence harm-reduction strategy\r\n\r\nNo gun or no ammo = no shooting'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Ban semi auto rifles w\ndetachable magazines and handguns as part of a gun violence harm\nreduction strategy\r\n\r\nNo gun or no ammo \n no shooting'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Ban semi auto rifles w
# detachable magazines and handguns as part of a gun violence harm
# reduction strategy
#
# No gun or no ammo
#  no shooting
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Today is your day! Your mountain is waiting, so . . . get on your way! – Dr. Seuss'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Today is your day\n Your mountain is waiting\n so \n \n \n get on your way\n \n Dr\n Seuss'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Today is your day
#  Your mountain is waiting
#  so
#
#
#  get on your way
#
#  Dr
#  Seuss
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 18 times)
# --------------------------------------------------------------------------------
# "I'm an astronomy author and photographer. My ebook, Nightscapes and Time-Lapses, is available thru my website at amazingsky.com/NightscapesBook."
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'I\nm an astronomy author and photographer\n My ebook\n Nightscapes and Time\nLapses\n is available thru my website at amazingsky.com\nNightscapesBook\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# I
# m an astronomy author and photographer
#  My ebook
#  Nightscapes and Time
# Lapses
#  is available thru my website at amazingsky.com
# NightscapesBook
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 6 times)
# --------------------------------------------------------------------------------
# 'Official City of Calgary local government Twitter account. Keep up with City news, services, programs, events and more. Not monitored 24/7.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Official City of Calgary local government Twitter account\n Keep up with City news\n services\n programs\n events and more\n Not monitored 24/7\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Official City of Calgary local government Twitter account
#  Keep up with City news
#  services
#  programs
#  events and more
#  Not monitored 24/7
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 36 times)
# --------------------------------------------------------------------------------
# 'Award Winning Professional Artist, Photographer.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Award Winning Professional Artist\n Photographer\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Award Winning Professional Artist
#  Photographer
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'Dedicated non-follower of fashion. Follows & Retweets not endorsements. No DMs please.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Dedicated non\nfollower of fashion\n Follows \n Retweets not endorsements\n No DMs please\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Dedicated non
# follower of fashion
#  Follows
#  Retweets not endorsements
#  No DMs please
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 4 times)
# --------------------------------------------------------------------------------
# 'Spot the photographer. Dad, husband, chaser of Aurora, teacher, lover of BBQ, nature, and the city I call home. DM for photographic inquiries or to send me beer'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Spot the photographer\n Dad\n husband\n chaser of Aurora\n teacher\n lover of BBQ\n nature\n and the city I call home\n DM for photographic inquiries or to send me beer'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Spot the photographer
#  Dad
#  husband
#  chaser of Aurora
#  teacher
#  lover of BBQ
#  nature
#  and the city I call home
#  DM for photographic inquiries or to send me beer
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Satire and parody. Below the real Western Standard. Follow our verified sister publication, @AlbertaRpt, in case Elon closes our doors.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Satire and parody\n Below the real Western Standard\n Follow our verified sister publication\n @AlbertaRpt\n in case Elon closes our doors\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Satire and parody
#  Below the real Western Standard
#  Follow our verified sister publication
#  @AlbertaRpt
#  in case Elon closes our doors
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 8 times)
# --------------------------------------------------------------------------------
# 'Progressive Canadian🇨🇦! ❤️travel✈️/photography📷/hiking & mountains🥾⛰Alberta, we need for save this province & fire the UCP!'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Progressive Canadian\n\n\n \n\ntravel\n\n\nphotography\n\nhiking \n mountains\n\nAlberta\n we need for save this province \n fire the UCP\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Progressive Canadian
#
#
#
#
# travel
#
#
# photography
#
# hiking
#  mountains
#
# Alberta
#  we need for save this province
#  fire the UCP
#
# ================================================================================
#
#
# ...
# --------------------------------------------------------------------------------
# 'Father, Brother, son, and fan to many'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Father\n Brother\n son\n and fan to many'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Father
#  Brother
#  son
#  and fan to many
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'Queer lefty-liberal nerd for #StarTrek, dogs, politics. Tweets about #HigherEd, #CdnPSE, & #EMChat. Likes wearing hats. He/Him. 𝗣𝗲𝗿𝘀𝗼𝗻𝗮𝗹 𝗮𝗰𝗰𝗼𝘂𝗻𝘁.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Queer lefty\nliberal nerd for \nStarTrek\n dogs\n politics\n Tweets about \nHigherEd\n \nCdnPSE\n \n \nEMChat\n Likes wearing hats\n He\nHim\n \n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Queer lefty
# liberal nerd for
# StarTrek
#  dogs
#  politics
#  Tweets about
# HigherEd
#
# CdnPSE
#
#
# EMChat
#  Likes wearing hats
#  He
# Him
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'The wisdom was created before any thing, the intelligence that disposes every thing comes from farther than the beginning of time.\r\nking 👑 Salomon.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'The wisdom was created before any thing\n the intelligence that disposes every thing comes from farther than the beginning of time\n\r\nking \n Salomon\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# The wisdom was created before any thing
#  the intelligence that disposes every thing comes from farther than the beginning of time
#
# king
#  Salomon
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'T1D Goalie Dad..Oil Sands Worker..Unapologetically Canadian Past-President Nanaimo-Ladysmith Conservative EDA…views are my own!!'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'T1D Goalie Dad\n\nOil Sands Worker\n\nUnapologetically Canadian Past\nPresident Nanaimo\nLadysmith Conservative EDA\nviews are my own\n\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# T1D Goalie Dad
#
# Oil Sands Worker
#
# Unapologetically Canadian Past
# President Nanaimo
# Ladysmith Conservative EDA
# views are my own
#
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# "Home of the staff of the World's Largest Game Store"
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Home of the staff of the World\ns Largest Game Store'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Home of the staff of the World
# s Largest Game Store
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'I love sports, politics, and have Aspergers. Keeping air travel safe.           Spanish, French, and Italian student.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'I love sports\n politics\n and have Aspergers\n Keeping air travel safe\n           Spanish\n French\n and Italian student\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# I love sports
#  politics
#  and have Aspergers
#  Keeping air travel safe
#            Spanish
#  French
#  and Italian student
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'A geordie exiled to Ireland and loving it. Trying to gt the hang of all this social media stuff, being non socialable its hard lol'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'A geordie exiled to Ireland and loving it\n Trying to gt the hang of all this social media stuff\n being non socialable its hard lol'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# A geordie exiled to Ireland and loving it
#  Trying to gt the hang of all this social media stuff
#  being non socialable its hard lol
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# '🐱☕️🍫🏒👜💙'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# '\n\n\n\n\n\n\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
#
#
#
#
#
#
#
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'Canadian by choice.📍#yegdt. Leftie. Foodie. Multilingual. Urban/international in outlook. Social scientist by trade. Not a Tweet-sized communicator by nature.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Canadian by choice\n\n\nyegdt\n Leftie\n Foodie\n Multilingual\n Urban\ninternational in outlook\n Social scientist by trade\n Not a Tweet\nsized communicator by nature\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Canadian by choice
#
#
# yegdt
#  Leftie
#  Foodie
#  Multilingual
#  Urban
# international in outlook
#  Social scientist by trade
#  Not a Tweet
# sized communicator by nature
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'Snacks, beers, motorcycles, DIY projects for life ✌🏼 BIPOC female, fighting that good fight in #yyc ✊🏼 Bitcoin. Be excellent to each other🤘🏼'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Snacks\n beers\n motorcycles\n DIY projects for life \n\n BIPOC female\n fighting that good fight in \nyyc \n\n Bitcoin\n Be excellent to each other\n\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Snacks
#  beers
#  motorcycles
#  DIY projects for life
#
#  BIPOC female
#  fighting that good fight in
# yyc
#
#  Bitcoin
#  Be excellent to each other
#
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 2 times)
# --------------------------------------------------------------------------------
# 'Bullied, rejected many times. Fell and stood for so many years. Invisible most of the time. Making people laugh is my strength,  but deep inside Im broken 💔.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Bullied\n rejected many times\n Fell and stood for so many years\n Invisible most of the time\n Making people laugh is my strength\n  but deep inside Im broken \n\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Bullied
#  rejected many times
#  Fell and stood for so many years
#  Invisible most of the time
#  Making people laugh is my strength
#   but deep inside Im broken
#
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'Politics. Oilers.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Politics\n Oilers\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Politics
#  Oilers
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'Mediocre white man. Software engineer. Node.js team. Architect and DX lead @neofinancial. Sandwich enthusiast. He/him. @iansu@mas.to.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Mediocre white man\n Software engineer\n Node\njs team\n Architect and DX lead @neofinancial\n Sandwich enthusiast\n He\nhim\n @iansu@mas\nto\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Mediocre white man
#  Software engineer
#  Node
# js team
#  Architect and DX lead @neofinancial
#  Sandwich enthusiast
#  He
# him
#  @iansu@mas
# to
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'Nerdy guy who likes hockey and punk rock!'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Nerdy guy who likes hockey and punk rock\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Nerdy guy who likes hockey and punk rock
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'Song Writer-Lover of the Creator, Lorna, Bear, Kass, Stella, Mao Mao Treaty 6/MNA4   #SickNotWeak Tweets mine but brutally honest @steelers Fan'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Song Writer\nLover of the Creator\n Lorna\n Bear\n Kass\n Stella\n Mao Mao Treaty 6\nMNA4   \nSickNotWeak Tweets mine but brutally honest @steelers Fan'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Song Writer
# Lover of the Creator
#  Lorna
#  Bear
#  Kass
#  Stella
#  Mao Mao Treaty 6
# MNA4
# SickNotWeak Tweets mine but brutally honest @steelers Fan
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'Radical Downtown Urbanite\r\nThe other place: @chrisdoyle78@yyc.bike'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Radical Downtown Urbanite\r\nThe other place\n @chrisdoyle78@yyc\nbike'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Radical Downtown Urbanite
# The other place
#  @chrisdoyle78@yyc
# bike
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'Formerly Agent for The Attorney General of Canada, Department of Justice, Alberta,. Currently, Author and International Trade Consultant, Alberta.'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Formerly Agent for The Attorney General of Canada\n Department of Justice\n Alberta\n\n Currently\n Author and International Trade Consultant\n Alberta\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Formerly Agent for The Attorney General of Canada
#  Department of Justice
#  Alberta
#
#  Currently
#  Author and International Trade Consultant
#  Alberta
#
# ================================================================================
#
#
# ================================================================================
# [ORIGINAL RECORD] (Appears 1 time)
# --------------------------------------------------------------------------------
# 'Snow Valley Racing delivers competitive ski racing for athletes from 4 to 18 years of age through a variety of professionally run programs. Links 👇🏼👇🏼👇🏼'
#
# [MODIFIED RECORD (Non-alphanumeric → Newline, preserving times/emails/URLs)]:
# --------------------------------------------------------------------------------
# 'Snow Valley Racing delivers competitive ski racing for athletes from 4 to 18 years of age through a variety of professionally run programs\n Links \n\n\n\n\n\n'
#
# [MODIFIED RECORD with new lines]:
# --------------------------------------------------------------------------------
# Snow Valley Racing delivers competitive ski racing for athletes from 4 to 18 years of age through a variety of professionally run programs
#  Links
#
#
#
#
#
#
# ================================================================================
#
#
# All non-alphanumeric characters in the 'Data' column have been replaced with newlines.
